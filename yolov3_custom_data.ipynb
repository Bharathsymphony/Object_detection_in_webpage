# %%
# go to Runtime
# Change runtime type
# under hardware accelerator, open drop down list, select GPU and save

# mount the google drive
from google.colab import drive
drive.mount('/content/drive')

# !nvidia-smi
# Out:
# Mounted at /content/drive
# Mon Mar 25 08:20:23 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
 # !chmod 755 /content/drive/MyDrive/darknet

# %%
# # changing current directory to the google drive
# %cd '/content/drive/My Drive'
# Out:
# /content/drive/My Drive

# %%
# # changing current directory to the google drive
# %cd '/content/drive/My Drive'

# # cloning darknet repo, this will create a folder, darknet
# !git clone https://github.com/AlexeyAB/darknet

# # going to the darknet folder and getting the weights
# %cd darknet
# !wget http://pjreddie.com/media/files/darknet53.conv.74

# # make changes in the Makefile to use GPU for training
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile

# # compiling
# !make
# Out:
# /content/drive/My Drive
# Cloning into 'darknet'...
# remote: Enumerating objects: 15833, done.
# remote: Total 15833 (delta 0), reused 0 (delta 0), pack-reused 15833
# Receiving objects: 100% (15833/15833), 14.39 MiB | 11.33 MiB/s, done.
# Resolving deltas: 100% (10666/10666), done.
# Updating files: 100% (2056/2056), done.
# /content/drive/My Drive/darknet
# --2024-03-24 11:54:10--  http://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 162.0.215.52
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://pjreddie.com/media/files/darknet53.conv.74 [following]
# --2024-03-24 11:54:10--  https://pjreddie.com/media/files/darknet53.conv.74
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
# ...

# %%
# %cd '/content/drive/My Drive/darknet'

# unzipping custom data to data folder
# !unzip -uq custom/custom_data.zip -d data

# copying the below files to data folder
# !cp custom/classes.names data
# !cp custom/obj.data data
# !cp custom/train.txt data
# !cp custom/test.txt data

# copying the config files to cfg folder
# !cp custom/yolov3_custom_train.cfg cfg
# !cp custom/yolov3_custom_test.cfg cfg

# %%
# !chmod +x ./darknet
# begin training by running this cell
# %cd '/content/drive/My Drive/darknet'
# !./darknet detector train data/obj.data cfg/yolov3_custom_train.cfg darknet53.conv.74 -dont_show

# this will create weight files in backup folder inside darknet
# when the training is completed, you'll see a file named
# yolov3_custom_train_final.weights
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.747249), count: 10, class_loss = 0.565946, iou_loss = 0.514573, total_loss = 1.080519
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.785725), count: 6, class_loss = 0.036796, iou_loss = 0.150982, total_loss = 0.187779
#  total_bbox = 466069, rewritten_bbox = 0.063510 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.795118), count: 4, class_loss = 0.087421, iou_loss = 0.074947, total_loss = 0.162368
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.794070), count: 6, class_loss = 0.025938, iou_loss = 0.247004, total_loss = 0.272942
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.771185), count: 2, class_loss = 0.061535, iou_loss = 0.088007, total_loss = 0.149543
# ...

# %%
# %cd '/content/drive/My Drive/darknet'
# Out:
# /content/drive/My Drive/darknet

# %%
# !chmod +x ./darknet
# to test model with images, upload the images in the darknet folder
# this way you'll only have to write the name of the image instead of the entire path

# !./darknet detector train data/obj.data cfg/yolov3_custom_train.cfg backup/yolov3_custom_train_last.weights -thresh 0.3

# this will create a image, 'predictions.jpg' in the darknet folder
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.909184), count: 6, class_loss = 0.000001, iou_loss = 0.021985, total_loss = 0.021985
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.893676), count: 17, class_loss = 0.000605, iou_loss = 0.111447, total_loss = 0.112052
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.853418), count: 11, class_loss = 0.005701, iou_loss = 0.186122, total_loss = 0.191823
#  total_bbox = 653045, rewritten_bbox = 0.054361 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.813974), count: 1, class_loss = 0.000011, iou_loss = 0.016882, total_loss = 0.016893
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.867101), count: 7, class_loss = 0.243343, iou_loss = 0.121238, total_loss = 0.364581
# ...

# %%
# !chmod +x ./darknet
# to test model with images, upload the images in the darknet folder
# this way you'll only have to write the name of the image instead of the entire path

# !./darknet detector test data/obj.data cfg/yolov3_custom_test.cfg backup/yolov3_custom_train_last.weights 24.jpg -thresh 0.3

# this will create a image, 'predictions.jpg' in the darknet folder
# Out:
#  CUDA-version: 12020 (12020), cuDNN: 8.9.6, GPU count: 1
#  OpenCV version: 4.5.4
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
# !chmod +x ./darknet
# to test model with images, upload the images in the darknet folder
# this way you'll only have to write the name of the image instead of the entire path

# !./darknet detector test data/obj.data cfg/yolov3_custom_test.cfg backup/yolov3_custom_train_last.weights 25.jpg -thresh 0.3

# this will create a image, 'predictions.jpg' in the darknet folder
# Out:
#  CUDA-version: 12020 (12020), cuDNN: 8.9.6, GPU count: 1
#  OpenCV version: 4.5.4
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...
